# %% [markdown]
# ### Analyzing Image Data Augmentation settings
#
# The code used in this blogpost was used as a reference: https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/

# %%
import numpy as np
from numpy import expand_dims
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# Out:
# 2021-11-19 11:03:11.308162: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ### Testing without featurewise centering and standard deviation normalization

# %%
# load the image
img = load_img('test_images/patient00005_view1_frontal.png')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode="constant",
    cval=0.0
)

# prepare iterator
it = datagen.flow(samples, batch_size=1)
f = pyplot.figure(figsize=(13, 13))
# generate samples and plot
for i in range(9):
    # define subplot
    f.add_subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# load the image
img = load_img('test_images/patient00005_view2_lateral.png')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode="constant",
    cval=0.0
)

# prepare iterator
it = datagen.flow(samples, batch_size=1)
f = pyplot.figure(figsize=(13, 13))
# generate samples and plot
for i in range(9):
    # define subplot
    f.add_subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ### Testing with featurewise centering and standard deviation normalization

# %%
# load the image
img = load_img('test_images/patient00005_view1_frontal.png')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode="constant",
    cval=0
)

training_data_mean = np.load("../../misc/calculated_chexpert_training_dataset_mean_and_std_values/CheXpert_training_set_mean.npy")
training_data_std = np.load("../../misc/calculated_chexpert_training_dataset_mean_and_std_values/CheXpert_training_set_std.npy")

datagen.mean = training_data_mean
datagen.std = training_data_std

print(datagen.mean)
print(datagen.std)

# prepare iterator
it = datagen.flow(samples, batch_size=1)
f = pyplot.figure(figsize=(13, 13))
# generate samples and plot
for i in range(9):
    # define subplot
    f.add_subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0]
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[108.86367]]]
# [[[82.375175]]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# load the image
img = load_img('test_images/patient00005_view2_lateral.png')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode="constant",
    cval=0.0
)

training_data_mean = np.load("../../misc/calculated_chexpert_training_dataset_mean_and_std_values/CheXpert_training_set_mean.npy")
training_data_std = np.load("../../misc/calculated_chexpert_training_dataset_mean_and_std_values/CheXpert_training_set_std.npy")

datagen.mean = training_data_mean
datagen.std = training_data_std

print(datagen.mean)
print(datagen.std)

# prepare iterator
it = datagen.flow(samples, batch_size=1)
f = pyplot.figure(figsize=(13, 13))
# generate samples and plot
for i in range(9):
    # define subplot
    f.add_subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0]
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[108.86367]]]
# [[[82.375175]]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
